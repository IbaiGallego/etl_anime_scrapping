# %% [markdown]
# # Anime Scrapping ETL

# %% [markdown]
# ## Imports

# %%
import requests

from bs4 import BeautifulSoup as bs

import pandas as pd
pd.set_option('display.max_columns', None)

import multiprocessing as mp

from tqdm.notebook import tqdm

import time

# %% [markdown]
# ## CSV and Columns

# %%
anime = pd.read_csv('../data/anime.csv')

# %%
old_colnames = anime.columns
new_colnames = [name.lower().replace(' ', '_').replace('-','_') for name in old_colnames]

anime.rename(columns=dict(zip(old_colnames, new_colnames)), inplace=True)

del_cols = ['score_1','score_2','score_3','score_4','score_5','score_6','score_7','score_8','score_9','score_10','dropped','plan_to_watch','on_hold','completed','watching','favorites','popularity']

anime.drop(columns=del_cols, inplace=True)

# %% [markdown]
# ## Wikipedia Function

# %%
anime.head(3)
# Out:
#    mal_id                             name score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
#
#                                               genres            english_name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
#
#     japanese_name   type episodes                        aired    premiered  \
# 0       カウボーイビバップ     TV       26  Apr 3, 1998 to Apr 24, 1999  Spring 1998
# 1  カウボーイビバップ 天国の扉  Movie        1                  Sep 1, 2001      Unknown
# 2           トライガン     TV       26  Apr 1, 1998 to Sep 30, 1998  Spring 1998
#
#                 producers                             licensors   studios  \
# 0           Bandai Visual      Funimation, Bandai Entertainment   Sunrise
# 1  Sunrise, Bandai Visual           Sony Pictures Entertainment     Bones
# 2    Victor Entertainment  Funimation, Geneon Entertainment USA  Madhouse
#
#      source         duration                          rating ranked  members
# 0  Original  24 min. per ep.  R - 17+ (violence & profanity)   28.0  1251960
# 1  Original    1 hr. 55 min.  R - 17+ (violence & profanity)  159.0   273145
# 2     Manga  24 min. per ep.       PG-13 - Teens 13 or older  266.0   558913

# %%
def wiki_dir(title): # Entra una lista de titulos
    
    res = 'unknown'
    
    url_wiki = 'https://en.wikipedia.org/wiki/'
    
    url= url_wiki + title.replace(' ','_')
   
    # Intenta encontrar el link y parsearlo

    try:
        
        html = requests.get(url).content
        
        soup = bs(html, "html.parser")
        
        # Prueba class_='infobox'
        
        if str(soup.find('table', class_='infobox')) != 'None':
                                                                       
            sauce = soup.find('table', class_='infobox')

            noodle = sauce.find_all('tr')
            
        # Prueba class_='infobox infobox_v2'
            
        elif str(soup.find('table', class_='infobox infobox_v2')) != 'None': 
            
            sauce = soup.find('table', class_='infobox infobox_v2')

            noodle = sauce.find_all('tr')
        
        # No encuentra la tabla que buscamos
        
        else: 
            
            pass
        
        # Loop que busca el th 'directed by' en todas las filas de la tabla y devuelve el nombre del director.
        
        for row in noodle:

            if row.find('th') == None:
                
                continue
                
            elif row.find('th').text.lower().replace('\xa0','') == 'directedby':
                
                res = row.find('td').text
            
            else:
                
                continue
        
        # Si se completa el loop sin haber conseguido un director devuelve esto.
                
        return res
        
    except:
        
        return 'fallo'

# %%
from joblib import Parallel, delayed

# %%
paralelo = Parallel(n_jobs=4,  verbose=True)


anime['director'] = paralelo(delayed(wiki_dir)(title) for title in anime.english_name)
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=4)]: Done 1242 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=4)]: Done 1792 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=4)]: Done 2442 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=4)]: Done 3192 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=4)]: Done 4042 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=4)]: Done 4992 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=4)]: Done 6042 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=4)]: Done 7192 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=4)]: Done 8442 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=4)]: Done 9792 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=4)]: Done 11242 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=4)]: Done 12792 tasks      | elapsed: 19.0min
# [Parallel(n_jobs=4)]: Done 14442 tasks      | elapsed: 21.2min
# [Parallel(n_jobs=4)]: Done 16192 tasks      | elapsed: 23.4min
# [Parallel(n_jobs=4)]: Done 17562 out of 17562 | elapsed: 26.9min finished

# %%
anime.director.unique()
# Out:
# array(['Shinichirō Watanabe', 'fallo', 'Satoshi Nishimura',
#        'Shūkō Murase', 'Tatsuya Nagamine', 'Li Yun Chan', 'unknown',
#        'Hiroshi Kōjina', 'Shinji Takamatsu', 'Takayuki Inagaki',
#        'Hiroshi Hamasaki', 'Tomohiro Hirata', 'Yasunao Aoki',
#        '\nHideaki Anno\nMasayuki (assistant)\nKazuya Tsurumaki (assistant)\n',
#        'Kōichi Mashimo', 'Hiroaki Gohda', 'Kiyoko Sayama',
#        'Hiroshi Nishikiori', 'Masami Shimoda', 'Koichi Ohata',
#        'Morio Asaka', 'Yū Kō', 'Koji YoshikawaNobuyoshi Habara',
#        'Iku Suzuki', 'Shinichi Omata[a]', 'Katsuichi Nakayama',
#        'Takahiro Omori', 'Takayuki Hamana', 'Keizou Kusakawa',
#        'Naoto Hosoda', 'Yoshikazu Yasuhiko', 'Yoshiyuki Tomino',
#        'Masashi Ikeda', 'Mitsuo Fukuda', 'Yasuhiro Imagawa',
#        'Yukio Takahashi', 'Masakazu Obara', 'Hatsuki Tsuji',
#        'Hajime Kamegaki', 'Shigeyasu Yamauchi', 'Yuji Mutoh',
#        'Takeo Takahashi', 'Tatsuo Satō', 'Hiroaki Sakurai',
#        'Yoshihide Ibata', 'Nanako Shimazaki', 'Nobuo Tomisawa',
#        'Misato Takada', 'Kazuhiro FuruhashiKeitaro Motonaga',
#        'Hiroshi Ishidori (Chief)Akira Mano', 'Liu Chang',
#        'Masahiko Murata', 'Tetsuya Yanagisawa',
#        'Hideaki AnnoHiroki Sato[a]', 'Shouji Saeki', 'Hideki Takayama',
#        'Bob Shirohata', 'Goichi Suda',
#        'Tsuneo KobayashiHikari Kurihara (#40)', 'Joji Furuta',
#        'Akiyuki Shinbo', 'Toshiyuki Kato', 'Akitaro Daichi',
#        'Shigeru Kimiya', 'Toshifumi KawaseYūzō Satō', 'Tomoki Kyoda',
#        'Toshifumi Takizawa', 'Sōichi Masui', 'Gorō Taniguchi',
#        'Toshifumi Kawase', 'Hayato Date',
#        'Kōichi MashimoHiroshi Morioka (#27–52)', 'Takeshi Mori',
#        'Kazuki Akane', 'Yoshiaki Iwasaki', 'Shinichiro Kimura',
#        'Shōji Kawamori', 'Yasunori Ide', 'Kunihisa Sugishima',
#        'Masaharu Okuwaki', 'Kazuaki Seki', 'Tensai Okamura',
#        'Koichi Chigira', 'Koji Masunari', 'Ryo Nishimura',
#        'Kaoru Tooyoka (eps 1, 2, 3, 4)',
#        'Hideki TakayamaYoshitaka Makino', 'Osamu Kasai', 'Mamoru Kanbe',
#        'Yutaka Uemura', 'Haruo Sotozaki (series director)Hitoyuki Matsui',
#        'Daisuke Nishio', 'Yuji Moriyama',
#        'Kenji Kodama (#1–118)Yasuichiro Yamamoto (#119–161, #163–218, #220–332, #667–677, #680–present)Masato Satō (#162, #219, #333–504)Kōjin Ochi (#505–666, #678–679)Nobuharu Kamanaka (#975–present)',
#        'Tomoki Kyoda[a]Hisatoshi Shimizu (Part 1)', 'Noriyuki Abe',
#        'Tsutomu Mizushima', 'Ei Aoki', 'Tōya Satō', 'Naohito Takahashi',
#        'Ken Iizuka', 'Takashi Watanabe', 'Tomoki Kobayashi',
#        'Takuya Igarashi', 'Makoto Shinkai', 'Rion Kujo',
#        'Tomokazu Tokoro (#1–4)Hiroyuki Tanaka (#5–7)Yasuhiro Matsumura (#8–10)Kenichi Suzuki (#8–10)',
#        'Shun Nakahara', 'Keiji Gotoh', 'Hideki Tonokatsu',
#        'Junichi Sakata (#1–4)Mitsuhiro Tōgō (#5–13)', 'Yasuchika Nagaoka',
#        'Kenichiro Komaya', 'Susumu Kudo', 'Koichi MashimoKoji Sawai',
#        'Koichi Mashimo (general director)Masayuki Yoshihara (#1)Koji Sawai (#2)Hiroshi Morioka (#3)',
#        'Kazuhisa Takenōchi', 'Keiji Hayakawa',
#        'Hiroyuki YamagaMasayuki Kojima (unit)', 'Osamu Kobayashi',
#        'Katsuhiko Nishijima', 'Satoshi Kon', 'Toshio Hirata',
#        'Masahiko Otsuka', 'Tsuneo Kobayashi', 'Hiroshi Ikehata',
#        'Ryūichi HirokiTakayuki Mizuno (assistant)', 'Hiroshi Watanabe',
#        'Shigeru Yamazaki', 'Tadao Nagahama (1–13)Osamu Dezaki (19–40)',
#        'Ryūtarō Nakamura', 'Takeyoshi YamamotoAyuko Tsukahara',
#        'Masashi Abe', 'Seiji Kishi', 'Ami Tomobuki',
#        'Takashi WatanabeKenji Yasuda (assistant)', 'Yoshitaka Fujimoto',
#        'Shinichi Watanabe', 'Tetsurō Amino', 'Ichiro Itano',
#        'Tomokazu Tokoro', 'Mitsuru Hongo', 'Takaharu Ozaki',
#        'Jun IshioRyuichi InomataKyoji OtsukaMasato Kuraibe',
#        'Seiji KishiKim Jung Ryool', 'Junji Nishimura', 'Naoyuki Kuzuya',
#        'Yoshimasa Hiraike', 'Kinji Yoshimoto', 'Toshihiro Hirano',
#        'Hiroyuki Ebata (#1)Takamasa Ikegami (#2)',
#        'Kunihiko IkuharaShingo Kaneko (assistant)Tōru Takahashi (assistant)',
#        'Hitoyuki Matsui', 'Takashi Nakamura', 'Hiroshi Nagahama',
#        'Masamitsu Hidaka', 'Jun Shishido', 'Junichi Sakata',
#        'Keitarō Motonaga', 'Junichi Sato (Chief)Takahiro Natori',
#        'Junji Shimizu', 'Tomohisa Taguchi', 'Takuya Satō',
#        'Akiyuki ShinboShin Oonuma[a]', 'Takao Kato', 'Yoshiaki Kawajiri',
#        'Osamu Nabeshima', 'Yūji Yamaguchi', 'Toshikatsu Tokoro',
#        'Haruki Kasugamori', 'Kunihiko Yuyama', 'Kazuo Yamazaki',
#        'Taikan Suga', 'Yoshihiro Takamoto',
#        'Masaki Kajishima[c]Keitarou Motonaga', 'Hiroko Tokita',
#        'Katsuya Korenaga', "Jun'ichi Sakata", 'Kazuyoshi Katayama',
#        'Hiroshi Kimura', 'Nagisa Miyazaki', 'Noriyoshi Nakamura',
#        'Keitaro Motonaga', "Koichi ChigiraMorio AsakaJun'ichi Sakata",
#        'Hiroshi Negishi', 'Takaaki Ishiyama',
#        'Yukio Kaizawa (#1, 4, 5, 8)Harume Kosaka (#2–3)Hiroki Shibata (#6)Hidehiko Kadota (#7)',
#        'Junichi Sato', 'Takeshi MoriKazuya Murata (unit director)',
#        'Nobuaki Nakanishi', 'Norio Kashima', 'Takahiro Natori',
#        'Toshiki Hirano (chief)Keitarō Motonaga', 'Leiji Matsumoto',
#        'Kazunori Mizuno',
#        'Hiroshi Fukutomi (part 3)  Makoto Moriwaki (part 1)  Shin Misawa (part 2)',
#        'Takeshi Yamaguchi', 'Katsuhito Akiyama',
#        'Junichi Sato (chief)Shogo Koumoto', 'Kimiharu Oguma',
#        'Yorifusa Yamaguchi', 'Masahiro Nakano', 'Asumi Matsumura',
#        'Yoshikata Nitta', 'Takahiro Okabi', 'Yousei Morino',
#        'Ryōsuke TakahashiGorō Taniguchi (assistant director)',
#        'Osamu Dezaki',
#        'Yasuhiro Nowatari (#1–98)Naohiro Terazaki (#99–159~167)',
#        'Yasuhiro Kuroda', 'Kunitoshi Okajima', 'Shunsuke Tada',
#        'Kurige Katsura', 'Masami Ōbari', 'Tsuyoshi Nagasawa',
#        'Toshiaki Iino', 'Toyoo Ashida (Chief)Hiromitsu Morita',
#        'Yasuhiro Takemoto', 'Yukina Hiiro', 'Masayuki Sakoi',
#        'Kenichi Kawamura', 'Shinji Ishihira',
#        'Yutaka Sato (Chief)Toshiya Shinohara', 'Nakamura Tetsuharu',
#        'Takeyuki Kanda[1]', 'Yoshiharu Ashino', 'Koichi Mashimo',
#        'Tetsuji Nakamura', 'Jōji ShimuraAhn Tae-kun', 'Mamoru Oshii',
#        'Yoshitomo Yonetani', 'Shigenori Kageyama', 'Yoshio Suzuki',
#        'Chizuru Miyawaki',
#        'Yutaka Satō (1-5)Jun Kawagoe (1-13)Takashi Sano (6-51)',
#        'Hiroyuki Kakudō (chief)Manabu Ono', 'Jun Kawagoe',
#        'Hideaki AnnoKazuya Tsurumaki', 'Tsukasa Sunaga',
#        'Mitsuru Hongo (#1-202)Keiichi Hara (#202-504)Yuji Muto (#505–present)',
#        'Toyoo Ashida', 'Yoshio Takeuchi', 'Yoshiten',
#        'Jun Kamiya (#1–2)Kiyoshi Murayama (#3)', 'Masayuki Kojima',
#        'Fumie Muroi', 'Yasuhito Kikuchi', 'Tomomi Mochizuki',
#        'Hisayuki Toriumi', 'Hiroshi Fukutomi',
#        'Akio Watanabe (episode 1 & 2) Toshiaki Tetsura (episode 3)',
#        'Hiroki Shibata', 'Mahiro Maeda',
#        'Noboru IshiguroHikaru Takanashi',
#        'Hidekazu OharaOsamu KobayashiKazuto NakazawaYasushi MurakiNobutaka Ito',
#        'Takashi Ikehata', 'Issei Kume', 'Keisuke ToyoshimaMari Asato',
#        'Kunihiro Mori', 'Shin-ichi Shoji', 'Takahiro Imamura',
#        'Tetsuo Imazawa',
#        'Rintaro (chief)Kazuyoshi Katayama (1)Koichi Chigira (2)Kazunari Kume (3)Masashi Ikeda (4)',
#        'Ryutaro Nakamura', 'Yoshitaka Koyama', 'Yoshiji Kigami',
#        'Tokihiro Sasaki', 'Yūsuke Yamamoto', 'Katsumi Minokuchi',
#        'Akio WatanabeToshikazu Matsubara', 'Megumu Ishiguro',
#        'Kazuhiro Ozawa',
#        'Yūji Moriyama (Chief)Junichi Sakata (#1, 3, 7)Tōru Yoshida (#2, 5)Osamu Mikasa (#4)Shin Misawa (#6)',
#        'Tsunekiyo Otani', 'Osamu Yamazaki', 'Shigeru Ueda',
#        'Tomek Bagiński', 'Kunitoshi Okajima[citation needed]',
#        'Hiroshi Ogawa, Kan Fukumoto', 'Bernard Deyriès, Hisayuki Toriumi',
#        "Katsuhisa Yamada (#1)Hisashi Abe (#2–3)Jun'ichi Sakata (#5)Akiyuki Shinbo (#6)",
#        'Tetsuro Amino', 'Fuminori Kizaki', 'Shinichi Masaki',
#        'Kenichi OhnukiNobuyasu FurukawaToshiyasu Kogawa', 'Makura Saki',
#        'Noboru Ishiguro', 'Yoriyasu Kogawa',
#        'Takamasa Ikegami (1)Akira Nishimori (2–3)', 'Kazuyoshi Yokota',
#        'Teruaki Murakami', 'Miyako Mizuno', 'Eiji Suganuma',
#        'Hiroshi SasagawaHiroyuki Fukushima', 'Osamu Dezaki (uncredited)',
#        'Akabane Hiroshi', 'Yasunori Urata', 'Itsuro Kawasaki',
#        'Hiroaki Satō (Chief)Shigeru Ueda',
#        'Akitaro DaichiHiroaki SakuraiAkira Suzuki', 'Hideaki Oba',
#        'Hirotoshi Takaya (#1–26)Hajime Kamegaki (#27–52)',
#        'Seiko SayamaMamoru Hamatsu', 'Hiroaki Yoshikawa', 'Osamu Sekita',
#        'Katsuyuki Kodera', 'Kenrana Namisato[1]', 'Nobuhiro Kondō',
#        'Haruka Ninomiya', 'Tetsurō Araki',
#        'Yoshio KazumiSupervision:Buronson', 'Masahiko Ohta',
#        'Masayuki Akehi', 'Katsushi Sakurabi', 'Shōichi Masuo',
#        'Koichi Sakamoto', 'Kou Matsuo', 'Kenichi Imaizumi',
#        'Kenji Kodama', 'Toshiyuki Kato (S1)Katsumi Ono (S2)',
#        'Kenichi Maejima', 'Toshiki Hirano', 'Fumio Maezono',
#        'Yukihiro Matsushita', 'Hirotoshi Takaya', 'Takeshi Ushigusa',
#        'Hidehito Ueda', 'Kokai Kakimoto',
#        'Hiroyuki MoritaKazuyoshi Yaginuma[a]', 'Tatsuyuki Nagai',
#        'Tomoyuki Kurokawa', 'Chiaki Kon', 'Fumitoshi Oizaki',
#        'Tsuneo Tominaga', 'Toshiaki Komura', 'Toshimasa Suzuki',
#        'Kiyohiro Omori', 'Kenichi Kasai',
#        'Kouji Makita (eps. 1–16)Yorifusa Yamaguchi (chief)',
#        'Tetsurō Amino (#1-2)Mamoru Hamatsu (#3-4)', 'Kazuhisa Takenouchi',
#        'Masahiro Hosoda', 'Ikka TsuchishidaEdage KatsuraKurige Katsura',
#        'Mikisuke HondaToshibumi ShimizuChikato KumizawaNozomi Aida',
#        '\nNishiura Masaki\nMurakami Masanori\n',
#        'Hitoyuki MatsuiTakuya Nonaka', 'Mitsuhiro Tougou',
#        'Tsukasa Dokite', 'Akiyuki Shinbo[a]Yuki Yase', 'Noriyo Sasaki',
#        'Yutaka Yamamoto', 'Shigenori Awai', 'Takashi Sogabe',
#        'Satoshi DezakiTsuneo Tominaga', 'Keizō Kusakawa',
#        'Kazuyuki HirokawaTakeshi AokiYasuhito Kikuchi', 'Kazuhiro Ochi',
#        'Shinji AramakiKenichi Yatagai', 'Hayao Miyazaki',
#        'Mamoru Hamatsu', 'Hiroyuki Imaishi', 'Motosuke Takahashi',
#        'Yōichi Ueda', 'Masami Hata', 'Konosuke Uda', 'Takeyuki Kanda',
#        'Hiroyuki FukushimaAkihiko Nishiyama (#3)Shinya Hanai (#4)',
#        'Fumihiko Takayama', 'Shinya Sadamitsu', 'Kazuya Hatazawa',
#        'Keiichiro Kawaguchi', 'Kinji YoshimotoSatoshi Urushihara',
#        'Seiji Mizushima', 'Michael Arias',
#        'Mitsuo IsoAssistants:Masaru YasukawaTomoya Takahashi',
#        'Kenichi Yatagai', 'Romanov Higa',
#        'Hidetoshi OomoriHiroyuki KitakuboHiroyuki KitazumeKatsuhiro OtomoKoji MorimotoMao LamdoTakashi NakamuraYasuomi Umetsu',
#        'Takahiro Okao', 'Tomoharu Katsumata (chief)Masamitsu Sasaki',
#        'Ryuuichi Nozaki', 'Hiroshi Shidara', 'Various', 'Hisashi Sugai',
#        'Tomoharu Katsumata', 'Tatsuji Yamazaki', 'Hiroki Hayashi',
#        'Tetsuo Yasumi', 'Takashi ImanishiTetsuro Amino', 'Norio Takanami',
#        'Kunihiko Yuyama (Chief)Norihiko SudoSada Natori',
#        'Katsuji Kanazawa', 'Akira Nishimori', 'Moribi Murano',
#        'Keizo Shimizu', 'Masami Oobari (eps 1 and 2)Aoi Takeuchi (ep 3)',
#        'Kiyoshi Matsuda', 'Makoto Moriwaki', 'Kōji Yoshikawa',
#        'Fumio Kurokawa', 'Kōzō Kusuba', 'Shigeo KoshiHiroshi Saitô',
#        'Hiroshi Saitô',
#        'Masaharu EndōHiroshi Saitō (1-33)Shigeo Koshi (34-52)',
#        'Ryōsuke Takahashi', 'Kazuo Sakai', 'Isao Takahata',
#        'Yoshio Kuroda', 'Yonehiko Watanabe', 'Nobuyoshi Habara',
#        'Kazunori Tanahashi', 'Noriyoshi SakumaKenji Ikeda',
#        'Tetsuya Endo', 'Mitsuo Hashimoto', 'Manabu Ono',
#        'Yukio Nishimoto', 'Seitarō Hara', 'Tadao Nagahama',
#        'Hiroshi Sasagawa', 'Nobuhiro Kondo', 'Masakazu Higuchi',
#        'Norihiko Nagahama', 'Kenji Yasuda (Chief)Tatsufumi Itō',
#        'Shin Oonuma', 'Tetsuaki Matsuda (Chief)Yasuhiro Kuroda[a]',
#        'Kōichi Mashimo (chief)Seiji Okuda', 'Yoshisuke Yamaguchi',
#        'Masahiko Ōkura', 'Hiroshi Watanabe[1]',
#        'Takeo Takahashi (Chief)Hijiri Sanpei', 'Seiji Okuda',
#        'Shishō Igarashi (Chief)[A]Hisashi Saitō', 'Ken Ochiai',
#        'Masayoshi Nishida', 'Gisaburō Sugii (chief)Tatsuo Satō',
#        'Masami Annō', 'Hisayuki Toriumi (uncredited)Mamoru Oshii',
#        'Takaaki IshiyamaKazunori Mizuno',
#        'Toshio Takeuchi (#1)Satoshi Dezaki (#2–5)', 'Hirofumi Ogura',
#        'Naoyoshi Shiotani', 'Yasuhiro Matsumura', 'Takao Yotsuji',
#        'Hiroshi Saitō', 'Yasuhiro Yoshiura', 'Nobuo Onuki',
#        'Tomoaki Hosoyama', 'Hiroyuki Yano',
#        'Masatsugu ArakawaToyokazu Sakai (assistant)',
#        'Kazuhiro Furuhashi', 'Tomoyuki Kamimura', 'Masakatsu Iijima',
#        'Masaharu Tomoda', 'Ichirō Itano', 'Eiji OkabeKenjiro Yoshida',
#        'Ryō Yasumura', 'Satoshi Dezaki', 'Yoshiaki OkumuraSōji Yoshikawa',
#        'Atsushi Ōtsuki', 'Taku Sugiyama', 'Munenori Nawa', 'Ryuji Masuda',
#        'Yusaku Saotome', 'Minekazu Hirade', 'Tatsuya Ishihara',
#        'Hiroshi Sasagawa (chief)Hiroyuki Fukushima (1-21)Tsuneo Tominaga (22-34)',
#        'Katsuyoshi Yatabe', 'Lam Ngai Kai', 'Kozo Morishita',
#        'Tarō Iwasaki', 'Akira Shigino', 'Osamu Tezuka', 'Takahide Ogata',
#        'Akira Sugino', 'Katsuhisa Yamada', 'Masaaki Yuasa',
#        'Takashi Tanazawa', 'Tokizō Tsuchiya', 'Masayuki Hayashi',
#        'Mitsuko Kase', 'Ippei Kuri', 'Jun Takagi', 'Takeshi Shirato',
#        'Hiroshi Kugimiya', 'Kimio Ikeda', 'Katsumi Ono',
#        'Yoshiaki Okumura\xa0[ja]', 'Han-Jung-SukSoo-Hyun Kim',
#        'Osamu Inoue', 'Shunji Ōga', 'Takahiro Ikegami', 'Hideaki Ohba',
#        'Hiroshi Saito', 'Kōji Itō (Chief)Noboru Ishiguro',
#        'Takahiro Omori (chief)Kotomi Deai', 'Sayo Yamamoto',
#        'Takeyuki Kanda (episodes 1-10)Katsuhiko Taguchi (episodes 11-50)',
#        'Kiyoshi Egami', 'Hidenori Yamaguchi', 'Kouichi Kimura',
#        'Kiyoshi Fukumoto', '\nHisayuki Toriumi\nKazuyuki Hirokawa\n',
#        'Katsutoshi Sasaki', 'Kōichirō Sōtome', 'Masaharu Endō',
#        'Jutaro Oba', 'Naoki Uesugi', 'Takayoshi Suzuki',
#        'Toshiro Kuni, Tsuneyuki Miyamoto', 'Tsutomu Hanabusa',
#        'Masaaki Osumi', 'Kenjirou Okada',
#        'Masamune OchiaiKunihiko Okazaki',
#        'Akiyuki Shinbo (Chief)Tomokazu Tokoro', 'Yuzo Sato',
#        'Akiyuki Shinbo[i]Tomoyuki Itamura (#1–36)[j]', 'Kazuhiko Udagawa',
#        'Yūji Himaki', 'Hiroshi Taisenji', 'Yoshiki Yamakawa',
#        'Kiyoshi Murayama', 'Tsunehito NagakiOsamu Tezuka',
#        'Shinji Aramaki (Chief)Hiroyuki Kanbe', 'Mitsuyuki Masuhara',
#        'Naoko Yamada', 'Keiji Kawakubo', 'Koji Yoshikawa',
#        'Hisashi Sakaguchi', 'Hidefumi Takagi',
#        'Kazuyuki Okaseko (OVA 1)Hiroshi Yoshida (OVA 2)Shigenori Kageyama (OVA 3)',
#        "Ken'ichi Imaizumi", 'Rintaro', 'Yukio Abe', 'Hisashi Saitō',
#        'Kiminori Kusano', 'Kazumi Minagawa', 'Shoichi Masuo',
#        'Masaki Nishiura', 'Yuu Kou Junichi Sato', "Ken'ichi Kasai",
#        'Masaki Tachibana', 'Yugo Serikawa', 'Shinji Ushiro', 'Sato Ōkura',
#        'Hiraku Kaneko', 'Hiro KatsuokaKeiji Hayakawa',
#        'Shinji Ishihira (#1–6)Tetsuo Amino (#7–9)',
#        'Akiyuki ShinboMasahiro Sonoda',
#        'Hiroyuki YokoyamaMasahiko FukutomiTakajuki Kaneko',
#        'Kenji Nakamura', 'Hiroshi Sasagawa (Chief Director)Seitarō Hara',
#        'Eiichi Yamamoto', 'Kōichirō Hatsumi', 'Osamu Yamasaki',
#        'Yumi Kamakura', 'Atsushi Matsumoto', 'Tomohiko Itō',
#        'Shigeru Omachi (Japanese)Robert Barron (Saban)',
#        'Tomoharu Katsumata (ep. 1), Masamune Ochiai (ep. 2), Masayuki Akehi (ep. 3), Hiroshi Shidara (ep. 4), Yasuo Yamaguchi (ep. 5), Osamu Kasai (eps. 6, 10), Yoshikatsu Kasai (ep. 7), Tsunekiyo Otani (ep. 8), Kazukiyo Shigeno (ep. 9), Kazumi Fukushima (ep. 11), Akinori Orai (eps. 12-13), Tokiji Kaburaki (ep. 14), Yūgo Serikawa (ep. 15), Atsutoshi Umezawa (ep. 16), Tadao Okubo (ep. 17), Junichi Sato (ep. 18), Yukio Kaizawa (ep. 19), Hiroyuki Ebata (ep. 20)',
#        'Kōsuke Murayama', 'Kazuhiko Yamaguchi', 'Gō Koga',
#        'Yukihiro MiyamotoAkiyuki Shinbo', 'Yuu Kou',
#        'Kenichi KasaiNoriaki Akitaya', 'Shingo Natsume',
#        'Kazuyuki Okasako (Chief director)', 'Shigeharu Kaneko',
#        'Junichi Ishikawa', 'Hiroshi NegishiKunitoshi Okajima (Chief)',
#        'Toshinori Fukushima', 'Naoyuki Konno', 'Satoshi Ōsedo',
#        'Tetsuya Endo (#1–54)Yukio Kaizawa (#55–79)', 'Takashi Kawabata',
#        'Ryūichi Honda', 'Takaomi Kanasaki', 'Tatsuo Sato',
#        'Kōbun Shizuno', 'Shuhei Morita',
#        'Akiyuki ShinboYukihiro Miyamoto',
#        'Shingo SuzukiHiromichi KanazawaSusumu Kudō', 'Masato Tsuzino',
#        'Ken Mori (chief)Ryūtarō Suzuki', 'Hiroaki Ando', 'Toshiyuki Katō',
#        'Shōji Saeki', 'Koichi Hatsumi', 'Tomonobu Morikawa',
#        'Satoshi Kuwahara', 'Akifumi Zako', 'Takenori Mihara',
#        'Yoshimitsu Ohashi', 'Kenji Nagasaki', 'Kanta Kamei',
#        'Teruo Kogure', 'Shin Itagaki', 'Kenji Yasuda',
#        'Seiji KishiTomohisa Taguchi', 'Michiko Namiki, Shogo Miyaki',
#        'Kunihiko Ikuhara', 'Shinpei Ezaki',
#        'Jirō Fujimoto (#1)Hiroyuki Shimazu (#2)', 'Yoshinori Odaka [1]',
#        'Tatsuo Satō[a]Toshimasa Suzuki', 'Tensho', 'Itsuki Imazaki',
#        'Yoshifumi Sueda', 'Shigeyuki Miya', 'Yasuhiro Irie',
#        'Daigo Matsui', 'Shin Oonuma[a]Shinya Kawatsura', 'Yūji Kumazawa',
#        'Shōji Kawamori (Chief)Yoshimasa Hiraike', 'Tōru Kitahata',
#        'Narumi Kuroda', 'Tetsuya Tatamitani',
#        'Shin Oonuma  Takashi Sakamoto', 'Ayumu Watanabe', 'Takahiro Miki',
#        'Takuo Suzuki', 'Hiroshi Negishi (Chief)Tae-Heo Han',
#        'Masakazu Hashimoto', 'Tomoyuki KawamuraYoichi Fujita',
#        'Kō Matsuo', 'Naoyoshi ShiotaniKatsuyuki Motohiro',
#        'Atsuko Ishizuka', 'Hideki Okamoto', 'Masahiro Andō',
#        'Sho Tsukikawa', 'Kazuhiro Takamura', 'Asako Hyuga',
#        'Ryosuke Nakamura', 'Kotono Watanabe',
#        'Yuzuru TachikawaJun Shishido[a]', 'Yusuke Yamamoto',
#        'Yoshiyuki Fujiwara', 'Kei OikawaAssistant director:Shōta Imai',
#        'Toshiya Shinohara', 'Masahiro Takata', 'Takahiko Kyōgoku',
#        'Susumu Nitsukawa', 'Yōhei Suzuki', 'Toya Sato',
#        'Yoshinori Odaka[1]',
#        'Keitaro Motonaga (I–III)Jun Nakagawa (IV–V)', 'Daisuke Tsukushi',
#        'Kaori', 'Shishō Igarashi', 'Pippuya',
#        'Akitoshi YokoyamaAkira Mano (assistant)', 'Naoyuki Itō',
#        'Kazuya Murata', 'Tatsuya Yoshihara', 'Ryōsuke Nakamura',
#        'Kōtarō Ishidate & Toru Nakano (Sound Director)',
#        'Shinji IshihiraToshinori Watanabe[a]', 'Risako Yoshida',
#        'Shinya Kawatsura',
#        'Keizō KusakawaAssistant director:Harume Kosaka',
#        'Kousuke Murayama', 'Masayoshi Kawajiri',
#        '\nTeam Nico\n\nYū NobutaKaori HayashiTomomi KamiyaKenichi KonishiMami Sodeyama\n',
#        'Masayuki Yoshihara', 'Yasutaka Yamamoto', 'Taichi Ishidate',
#        'Hideki Itō (Chief)Kenji Nakamura',
#        'Seiya Numata (Chief)Masaomi Andō', 'Hideyo Yamamoto',
#        'Hikaru Sato', 'Eisaku Kawanami',
#        'Bonjin NagakiYasuo Yamaguchi (episode directors)', 'Fumiya Hojo',
#        'Sōbi Yamamoto', 'Kei Oikawa', 'Hiroshi Ikeda', 'Rie Matsumoto',
#        'Yūzō Satō', 'Hiroyuki Seshita (chief)Tadahiro Yoshihira',
#        'Katsuhisa Yamada, Jules Bass, Arthur Rankin Jr.',
#        'Seiki Sugawara', 'Kenichi Ishikura', 'Yasuomi Umetsu',
#        'Shinichirō Watanabe (chief)Shingo Natsume',
#        'Hiro Kaburaki (#1–3; Chief #4) Kazuhiro Yoneda (#4–7)',
#        'Toru Takahashi', 'Susumu Mitsunaka',
#        'Shunsuke Tada Tomoyuki Kurokawa', 'Hidekazu Satō',
#        'Hiroyuki Hashimoto', 'Tarou Iwasaki', 'Shigehito Takayanagi',
#        'Ayano Ohnoki', 'Yasuhiro Tanabe', 'Tomoyuki Kawamura',
#        'Katsuyuki Motohiro', 'Takeshi Furuta', 'Shinobu Sasaki',
#        'Shinpei Nagai', 'Masato Matsune', 'Toshinori Watanabe',
#        'Kenichi Shimizu', 'Hiroshi TakeuchiHiroshi Hamasaki',
#        'Michio Fukuda', 'Keita Kono', 'Yukio Kaizawa', 'Kazuya Iwata',
#        'Naoyoshi ShiotaniKiyotaka Suzuki',
#        'Shinichirō WatanabeAssistant:Yuzuru Tachikawa', 'Mitsue Yamazaki',
#        'Kazuya Miura', 'Noboru Iguchi',
#        'Hideki Araki (1)Takashi Nishikawa (2–3)', 'Ryūichi Hiroki',
#        'Chikara Sakurai', 'Kyōhei Ishiguro', 'Shinya Watada',
#        'Akiyuki Shinbo[a]Naoyuki Tatsuwa', 'Hiroyuki Kanbe',
#        'Masaomi Andō', 'Kazuhiro Yoneda', 'Masato Jinbo',
#        'Masahiko Otsuka (chief)Masanori Takahashi',
#        'Shūkō MuraseKōichi Hatsumi', 'Atsushi Nakayama', 'Akira Iwanaga',
#        'Kotomi Deai', 'Ikuo Geso', "Jun'ichi Wada",
#        'Akio TakamiTakao Kato', 'Shunji Iwai',
#        'Yoshiki Yamakawa (I)Hideki Tachibana (II–IV)', 'Noriaki Akitaya',
#        'Seiki Sugawara (#1–50)Hiroshi Ishiodori (#51–75)',
#        'Tomoki Takuno', 'Yuki TanadaMakoto KiyohiroTatsuo Kobayashi',
#        'Hisashi Ishii', 'Masato Sato',
#        'Keiichiro Kawaguchi (1)Tomio Yamauchi (6–12)', 'Ai Yoshimura',
#        'Satoru Kosaka', 'Hideki Tachibana (Chief)Masato Matsune',
#        'Yūichi SatōDaisuke Yamauchi', 'Hideaki Nakano',
#        'Shin OonumaJin Tamamura', 'Shōko Nakamura', 'Masaharu Watanabe',
#        'Minoru Yamaoka', 'Kotaro Tamura', 'Tomoya Takashima',
#        'Manabu OnoKenji Seto',
#        'Kimitoshi Chioka (#1–46)Morio Hatano (#28–76)Kōhei Hatano (#47–76)Tatsuya Nagamine (#77–131)Ryōta Nakamura (#77–131)',
#        'Tomohiro KawamuraYoshihiro Komori', 'Masaomi Ando',
#        'Haruo Sotozaki', 'Ten Shimoyama', 'Takeyuki Yanase',
#        'Yoichi Fujita', 'Yoshinori Odaka',
#        'Kenichi Kawamura[b]Masaharu Watanabe',
#        'Yasuhito KikuchiAtsushi Nakayama', 'Shinsuke Yanagi',
#        'Kazuya Nomura', 'Tetsurō Amino (chief director)Tomohiko Ohkubo',
#        'Satoshi Shimizu', 'Takao Abo', 'Satonobu Kikuchi', 'Yuu Nobuta',
#        'Yasuhiro Kimura', 'Yūta Murano', 'Yuki Ogawa', 'Satoshi Kuwabara',
#        'Akiyuki ShinboKenjirou Okada', 'Tetsuo Ichimura',
#        'Gorō Taniguchi (chief director)Noriaki Akitaya',
#        'Hiroshi Kobayashi', 'Hiroyuki Furukawa',
#        'Hisayoshi HirasawaTokihiro Sasaki', 'Masato Mitsuka',
#        'Kenji Nagasaki[a]Tomo Ōkubo (#39–51)[b]Masahiro Mukai (#64–)',
#        'Daizen Komatsuda', 'Hiroaki Akagi', 'Kōichi Sakamoto',
#        'Atsushi Nigorikawa', 'Kenshirō Morii', 'Shōta Ihata',
#        'Kyō Yatate', 'Seiki Takuno',
#        'Hiroyuki ImaishiAkira Amemiya (secondary)', 'Hideya Takahashi',
#        'Akira Iwanaga (season 1)  Itsuro Kawasaki (season 2)',
#        'Akira Iwamoto', 'Norihisa Hiranuma', 'Ryohei Takeshita',
#        'Youhei Suzuki', 'Li Haoling[a]Ken Andō',
#        'Shogo MiyakiShunsuke Shinada', 'Hiraku Kaneko[a]', 'Rarecho',
#        'Kiyotaka Oshiyama', 'Shingo SuzukiHiromitsu Kanazawa',
#        'Hiro Kaburagi', 'Noriaki AkitayaKazuo Miyake',
#        'Tatsuya IshiharaYasuhiro Takemoto[a]',
#        'Taichi IshidateHaruka Fujita[a]', 'Hideki Tachibana',
#        'Mirai Minato', 'Yoh Yoshinari', 'Liang Zhenzhe (Chief)Li Haoling',
#        'Naoya Fukushi', 'Kōbun Shizuno (Chief)  Odahiro Watanabe',
#        'Hiroshi Nishikori[a]Hirokazu Hanai',
#        'Hiroshi NishikioriKensuke Yamamoto',
#        'Takeo Takahashi[a]Hijiri Sanpei[b]Tooru Kitahata',
#        'Ryōichi Kuraya', 'Daisuke Yoshida', 'Yoshihiro Fukagawa',
#        'Katsuya Kikuchi', 'Manabu Okamoto', 'Hisayoshi Hirasawa[1]',
#        'Takashi Sakuma', 'Hiroyuki FurukawaYūki Ogawa (assistant)[3]',
#        'Shengjun YuXuegang ShiSong QingYi Shi', 'Daiki Tomiyasu',
#        'Fumitoshi Oizaki (chief)Naoyuki Konno', 'Tsukasa Nishiyama',
#        'Yoshimi Itazu', 'Yoshiaki Kyōgoku (S1–S2)Shin Tosaka (S3)',
#        'Takahiro Ikezoe', 'Seinosuke TanakaOsamu Nakayama',
#        'Kazuya Ichikawa', 'Masashi Kudō',
#        'Masahiro Hosoda[1] (#1–#13)Katsuya Asano (#14–#120)',
#        'Yasuto Nishikata', 'Takahiro Ikezoe (Chief)Kentaro Yamaguchi',
#        'Kazuaki Terasawa',
#        'Takeyuki Yanase (season 1)Yoshiaki Iwasaki (season 2)',
#        'Shūsei Morishita', 'Isamu Ueno',
#        'Akira Nishimori (#1–2)Toshirō Fujii (#3)Hiroko Kazui (#4)Minoru Ōhara (#5)Yukio Takahashi (#6, 11)Koichi Chigira (#7)Takaaki Ishiyama (#8)Shigatsu Yoshikawa (#9)Koji Morimoto (10)Kenzaburō Mori (#12)Eito Ifue[a] (#13)',
#        'Amika Kubo', 'Shin Matsuo',
#        'Yūhei SakuragiHiroki Matsūra[a]Tomoyuki Takae[a]', 'Kenji Seto',
#        'Jun AokiAoi Umeki (season 1)', 'Shin OonumaJin Tamamura[a]',
#        'Hisayoshi HirasawaSaori Tachibana', 'Tomohiro Furukawa',
#        'Seiji Kishi[a]Hiroyuki Hashimoto[a]Yoshihito Nishōji (#13–)',
#        'Atsushi Kobayashi', 'Nobuyoshi Nagayama',
#        'Takao Abo (season 1)  Masato Jinbo (season 2)  Hitoshi Haga (season 3)',
#        'Atsushi Nishigori', 'Son Seok-woo', 'Toshiyuki Kubooka',
#        'Hisashi Saitō (Chief)Shigeru UedaTakuo Kimura (#11–12)',
#        'Kazuyoshi Yaginuma', 'Tadahito Matsubayashi', 'Yoshihito Nishōji',
#        'Ouru Todoroki', 'Masafumi Tamura', 'Yoshimitsu Ōhashi', 'Mankyū',
#        'Gaku Nakatani (S1)Ryūtarō Suzuki (S1)Hiroyuki Yamaga (S2)',
#        'Shin Katagai', 'Kōnosuke UdaYasutaka Yamamoto',
#        'Takahiro MiuraTetsuto Satō', 'Tatsuki',
#        'Nobuyuki Takeuchi (chief)Kunihiko Ikuhara', 'Kitaro Kosaka',
#        'Kōsuke Kobayashi', 'Ryu Kaneda', 'Jōji FurutaRyō Andō[a]',
#        'Jin TamamuraYūichi Abe', 'Hideaki Iwami', 'Makoto Katō',
#        'Kentarō ŌtaniHitomi KitagawaAkihiko Takaishi',
#        'Kazuki AkaneYuuichi Takahashi[a]', 'Munehisa Sakai',
#        'Ayato Matsuda', 'Yukihiro Miyamoto', 'Kaoru Suzuki',
#        "Jun'ichi Yamamoto", 'Nobuharu Kamanaka', 'Fumiaki Usui',
#        'Yoshinobu Tokumoto', 'Yuki Yase (S1)Tatsuma Minamikawa (S2)',
#        'Shūhei Matsushita', 'Mai SakaiAya IgashiKeita Mizunami',
#        'Tomoaki Koshida', 'Sunghoo Park (S1)Shōta Goshozono (S2)',
#        'Keisuke Inoue', 'Takeo Takahashi[a]Naoyuki Tatsuwa',
#        'Daisuke Hiramaki', 'Tadahiro Yoshihira',
#        'Shinpei Ezaki (Chief)Tomoe Makino',
#        'Seiji Mizushima (chief)Daisuke Suzuki', 'Takahiro Horie',
#        'Kazuya Fujishiro', 'Shinmei Kawahara', 'Hidetoshi Takahashi',
#        'Hiroaki Andō', 'Takashi Sano', 'Jun Aoki', 'Tatsumi',
#        'Shin Oonuma (chief)Masafumi Tamura',
#        'Takashi SumidaOsamu KatayamaHisashi Ueda',
#        'Shin OonumaMirai Minato', 'Ryota Nakamura', 'Takuya Asaoka',
#        'Hiroki Ikeshita', 'Gorō Taniguchi (chief)Toshinori Fukushima',
#        'Yū Kinome', 'Masaya Fujimori', 'Shun EnokidoTakahito Sakazume',
#        'Masahiko Murata (S1)Kiyoko Sayama (S2)', 'Rensuke Oshikiri',
#        'Sunghoo Park[a]', 'Hirotaka Tokuda', 'Yoshihiro Nakamura',
#        'Kenta Ōnishi', 'Yoshiyuki Asai', 'Yū Nobuta', 'Yuki Watanabe',
#        'Shinji Ishihira (Chief)Yūji Suzuki (S1)Toshinori Watanabe (S2)',
#        'Jun Kamiya', 'Hisatoshi Shimizu', 'Shingo Suzuki',
#        'Masashi Ishihama', 'Hiroko Utsumi', 'Atsushi Takahashi',
#        'Tōichirō Rutō', 'Ryōsuke Aoike', 'Ryū NakayamaMasato Nakazono[a]',
#        'Masao Ōkubo', 'Masato Tamagawa', 'Yoshinobu Yamakawa'],
#       dtype=object)

# %%
anime
# Out:
#        mal_id                             name    score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 17558   48483                     Mieruko-chan  Unknown
# 17559   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 17560   48491      Yama no Susume: Next Summit  Unknown
# 17561   48492                    Scarlet Nexus  Unknown
#
#                                                   genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# 4              Adventure, Fantasy, Shounen, Supernatural
# ...                                                  ...
# 17557                   Adventure, Mystery, Supernatural
# 17558                       Comedy, Horror, Supernatural
# 17559  Mystery, Dementia, Horror, Psychological, Supe...
# 17560                   Adventure, Slice of Life, Comedy
# 17561                                    Action, Fantasy
#
#                           english_name                     japanese_name  \
# 0                         Cowboy Bebop                         カウボーイビバップ
# 1               Cowboy Bebop:The Movie                    カウボーイビバップ 天国の扉
# 2                               Trigun                             トライガン
# 3                   Witch Hunter Robin  Witch Hunter ROBIN (ウイッチハンターロビン)
# 4               Beet the Vandel Buster                            冒険王ビィト
# ...                                ...                               ...
# 17557                          Unknown                         盗墓笔记之秦岭神树
# 17558                          Unknown                           見える子ちゃん
# 17559  Higurashi:When They Cry – SOTSU                        ひぐらしのなく頃に卒
# 17560                          Unknown                ヤマノススメ Next Summit
# 17561                          Unknown                     SCARLET NEXUS
#
#         type episodes                         aired    premiered  \
# 0         TV       26   Apr 3, 1998 to Apr 24, 1999  Spring 1998
# 1      Movie        1                   Sep 1, 2001      Unknown
# 2         TV       26   Apr 1, 1998 to Sep 30, 1998  Spring 1998
# 3         TV       26   Jul 2, 2002 to Dec 24, 2002  Summer 2002
# 4         TV       52  Sep 30, 2004 to Sep 29, 2005    Fall 2004
# ...      ...      ...                           ...          ...
# 17557    ONA  Unknown              Apr 4, 2021 to ?      Unknown
# 17558     TV  Unknown                     2021 to ?      Unknown
# 17559     TV  Unknown                Jul, 2021 to ?  Summer 2021
# 17560     TV  Unknown                       Unknown      Unknown
# 17561     TV  Unknown                Jul, 2021 to ?  Summer 2021
#
#                                                producers  \
# 0                                          Bandai Visual
# 1                                 Sunrise, Bandai Visual
# 2                                   Victor Entertainment
# 3      TV Tokyo, Bandai Visual, Dentsu, Victor Entert...
# 4                                       TV Tokyo, Dentsu
# ...                                                  ...
# 17557                                            Unknown
# 17558                                           Kadokawa
# 17559                                            Unknown
# 17560                                           Kadokawa
# 17561                                  Bandai Namco Arts
#
#                                   licensors         studios        source  \
# 0          Funimation, Bandai Entertainment         Sunrise      Original
# 1               Sony Pictures Entertainment           Bones      Original
# 2      Funimation, Geneon Entertainment USA        Madhouse         Manga
# 3          Funimation, Bandai Entertainment         Sunrise      Original
# 4                                   Unknown  Toei Animation         Manga
# ...                                     ...             ...           ...
# 17557                               Unknown         Unknown         Novel
# 17558                               Unknown        Passione         Manga
# 17559                               Unknown         Unknown  Visual novel
# 17560                               Unknown            8bit         Manga
# 17561                               Unknown         Sunrise          Game
#
#               duration                          rating   ranked  members  \
# 0      24 min. per ep.  R - 17+ (violence & profanity)     28.0  1251960
# 1        1 hr. 55 min.  R - 17+ (violence & profanity)    159.0   273145
# 2      24 min. per ep.       PG-13 - Teens 13 or older    266.0   558913
# 3      25 min. per ep.       PG-13 - Teens 13 or older   2481.0    94683
# 4      23 min. per ep.                   PG - Children   3710.0    13224
# ...                ...                             ...      ...      ...
# 17557          Unknown                         Unknown  Unknown      354
# 17558          Unknown                         Unknown  Unknown     7010
# 17559          Unknown  R - 17+ (violence & profanity)  Unknown    11309
# 17560          Unknown       PG-13 - Teens 13 or older  Unknown     1386
# 17561          Unknown                         Unknown  Unknown      310
#
#                   director
# 0      Shinichirō Watanabe
# 1                    fallo
# 2        Satoshi Nishimura
# 3             Shūkō Murase
# 4         Tatsuya Nagamine
# ...                    ...
# 17557                fallo
# 17558                fallo
# 17559                fallo
# 17560                fallo
# 17561                fallo
#
# [17562 rows x 19 columns]

# %%
anime.to_csv('anime_2.csv', index=False)
